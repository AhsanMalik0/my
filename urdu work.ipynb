# %%
dic1={"ا":"ا","ب":"ب","پ":"پ","ت":"ت","ٹ":"ٹ","ث":"ث","ج":"ج","ح":"د","د":"ص","ص":"ط","ط":"","ی":"ی","ک":"ک","ہ":"ہ","ل":"ل","ن":"ن","ر":"ر","و":"و","م":"م","ع":"ع","غ":"غ"}

# %%
dic2={"ظ":"ظ","ض":"ض","ذ":"ذ","ّ":"ّ","ۃ":"ۃ","چ":"چ","خ":"خ","ي":"ي","گ":"گ","آ":"آ","ء":"ء","ۂ":"ۂ","ں":"ں","ڑ":"ڑ","ز":"ز","ژ":"ژ","ۓ":"ۓ","ۓ":"ۓ","ئ":"ئ"}

# %%
dic={}
dic.update(dic1)
dic.update(dic2)

# %%
dic
# Out:
# {'ا': 'ا',
#  'ب': 'ب',
#  'پ': 'پ',
#  'ت': 'ت',
#  'ٹ': 'ٹ',
#  'ث': 'ث',
#  'ج': 'ج',
#  'ح': 'د',
#  'د': 'ص',
#  'ص': 'ط',
#  'ط': '',
#  'ی': 'ی',
#  'ک': 'ک',
#  'ہ': 'ہ',
#  'ل': 'ل',
#  'ن': 'ن',
#  'ر': 'ر',
#  'و': 'و',
#  'م': 'م',
#  'ع': 'ع',
#  'غ': 'غ',
#  'ظ': 'ظ',
#  'ض': 'ض',
#  'ذ': 'ذ',
#  'ّ': 'ّ',
#  'ۃ': 'ۃ',
#  'چ': 'چ',
#  'خ': 'خ',
#  'ي': 'ي',
#  'گ': 'گ',
#  'آ': 'آ',
#  'ء': 'ء',
#  'ۂ': 'ۂ',
#  'ں': 'ں',
#  'ڑ': 'ڑ',
#  'ز': 'ز',
#  'ژ': 'ژ',
#  'ۓ': 'ۓ',
#  'ئ': 'ئ'}

# %%
import csv

# %%
lis1=[]
print(len(dic))
dic.values()
# Out:
# 39
# dict_values(['ا', 'ب', 'پ', 'ت', 'ٹ', 'ث', 'ج', 'د', 'ص', 'ط', '', 'ی', 'ک', 'ہ', 'ل', 'ن', 'ر', 'و', 'م', 'ع', 'غ', 'ظ', 'ض', 'ذ', 'ّ', 'ۃ', 'چ', 'خ', 'ي', 'گ', 'آ', 'ء', 'ۂ', 'ں', 'ڑ', 'ز', 'ژ', 'ۓ', 'ئ'])

# %%
for i in dic.values():
    for k in dic.values():
        j=i+k
        lis1.append(j)

# %%
lis1
# Out:
# ['اا',
#  'اب',
#  'اپ',
#  'ات',
#  'اٹ',
#  'اث',
#  'اج',
#  'اد',
#  'اص',
#  'اط',
#  'ا',
#  'ای',
#  'اک',
#  'اہ',
#  'ال',
#  'ان',
#  'ار',
#  'او',
#  'ام',
#  'اع',
#  'اغ',
#  'اظ',
#  'اض',
#  'اذ',
#  'اّ',
#  'اۃ',
#  'اچ',
#  'اخ',
#  'اي',
#  'اگ',
#  'اآ',
#  'اء',
#  'اۂ',
#  'اں',
#  'اڑ',
#  'از',
#  'اژ',
#  'اۓ',
#  'ائ',
#  'با',
#  'بب',
#  'بپ',
#  'بت',
#  'بٹ',
#  'بث',
#  'بج',
#  'بد',
#  'بص',
#  'بط',
#  'ب',
#  'بی',
#  'بک',
#  'بہ',
#  'بل',
#  'بن',
#  'بر',
#  'بو',
#  'بم',
#  'بع',
#  'بغ',
#  'بظ',
#  'بض',
#  'بذ',
#  'بّ',
#  'بۃ',
#  'بچ',
#  'بخ',
#  'بي',
#  'بگ',
#  'بآ',
#  'بء',
#  'بۂ',
#  'بں',
#  'بڑ',
#  'بز',
#  'بژ',
#  'بۓ',
#  'بئ',
#  'پا',
#  'پب',
#  'پپ',
#  'پت',
#  'پٹ',
#  'پث',
#  'پج',
#  'پد',
#  'پص',
#  'پط',
#  'پ',
#  'پی',
#  'پک',
#  'پہ',
#  'پل',
#  'پن',
#  'پر',
#  'پو',
#  'پم',
#  'پع',
#  'پغ',
#  'پظ',
#  'پض',
#  'پذ',
#  'پّ',
#  'پۃ',
#  'پچ',
#  'پخ',
#  'پي',
#  'پگ',
#  'پآ',
#  'پء',
#  'پۂ',
# ...

# %%
with open("urdu.csv","w",encoding="UTF-8")as file:
    filewriter=csv.writer(file)
    filewriter.writerow(lis1)

# %%
lis1=[]
for i in dic.values():
    for k in dic.values():
        for l in dic.values():
            j=i+k+l
            lis1.append(j)

# %%
lis1
# Out:
# ['ااا',
#  'ااب',
#  'ااپ',
#  'اات',
#  'ااٹ',
#  'ااث',
#  'ااج',
#  'ااد',
#  'ااص',
#  'ااط',
#  'اا',
#  'اای',
#  'ااک',
#  'ااہ',
#  'اال',
#  'اان',
#  'اار',
#  'ااو',
#  'اام',
#  'ااع',
#  'ااغ',
#  'ااظ',
#  'ااض',
#  'ااذ',
#  'ااّ',
#  'ااۃ',
#  'ااچ',
#  'ااخ',
#  'ااي',
#  'ااگ',
#  'ااآ',
#  'ااء',
#  'ااۂ',
#  'ااں',
#  'ااڑ',
#  'ااز',
#  'ااژ',
#  'ااۓ',
#  'اائ',
#  'ابا',
#  'ابب',
#  'ابپ',
#  'ابت',
#  'ابٹ',
#  'ابث',
#  'ابج',
#  'ابد',
#  'ابص',
#  'ابط',
#  'اب',
#  'ابی',
#  'ابک',
#  'ابہ',
#  'ابل',
#  'ابن',
#  'ابر',
#  'ابو',
#  'ابم',
#  'ابع',
#  'ابغ',
#  'ابظ',
#  'ابض',
#  'ابذ',
#  'ابّ',
#  'ابۃ',
#  'ابچ',
#  'ابخ',
#  'ابي',
#  'ابگ',
#  'ابآ',
#  'ابء',
#  'ابۂ',
#  'ابں',
#  'ابڑ',
#  'ابز',
#  'ابژ',
#  'ابۓ',
#  'ابئ',
#  'اپا',
#  'اپب',
#  'اپپ',
#  'اپت',
#  'اپٹ',
#  'اپث',
#  'اپج',
#  'اپد',
#  'اپص',
#  'اپط',
#  'اپ',
#  'اپی',
#  'اپک',
#  'اپہ',
#  'اپل',
#  'اپن',
#  'اپر',
#  'اپو',
#  'اپم',
#  'اپع',
#  'اپغ',
#  'اپظ',
# ...

# %%
with open("urdu_1.csv","w",encoding="UTF-8")as file:
    filewriter=csv.writer(file)
    filewriter.writerow(lis1)

# %%
lis1=[]
for i in dic.values():
    for k in dic.values():
        for h in dic.values():
            for n in dic.values():
                j=i+k+h+n
                lis1.append(j)

# %%
lis1
# Out:
# ['اااا',
#  'اااب',
#  'اااپ',
#  'ااات',
#  'اااٹ',
#  'اااث',
#  'اااج',
#  'اااد',
#  'اااص',
#  'اااط',
#  'ااا',
#  'ااای',
#  'اااک',
#  'اااہ',
#  'ااال',
#  'ااان',
#  'ااار',
#  'اااو',
#  'ااام',
#  'اااع',
#  'اااغ',
#  'اااظ',
#  'اااض',
#  'اااذ',
#  'اااّ',
#  'اااۃ',
#  'اااچ',
#  'اااخ',
#  'اااي',
#  'اااگ',
#  'اااآ',
#  'اااء',
#  'اااۂ',
#  'اااں',
#  'اااڑ',
#  'اااز',
#  'اااژ',
#  'اااۓ',
#  'ااائ',
#  'اابا',
#  'اابب',
#  'اابپ',
#  'اابت',
#  'اابٹ',
#  'اابث',
#  'اابج',
#  'اابد',
#  'اابص',
#  'اابط',
#  'ااب',
#  'اابی',
#  'اابک',
#  'اابہ',
#  'اابل',
#  'اابن',
#  'اابر',
#  'اابو',
#  'اابم',
#  'اابع',
#  'اابغ',
#  'اابظ',
#  'اابض',
#  'اابذ',
#  'اابّ',
#  'اابۃ',
#  'اابچ',
#  'اابخ',
#  'اابي',
#  'اابگ',
#  'اابآ',
#  'اابء',
#  'اابۂ',
#  'اابں',
#  'اابڑ',
#  'اابز',
#  'اابژ',
#  'اابۓ',
#  'اابئ',
#  'ااپا',
#  'ااپب',
#  'ااپپ',
#  'ااپت',
#  'ااپٹ',
#  'ااپث',
#  'ااپج',
#  'ااپد',
#  'ااپص',
#  'ااپط',
#  'ااپ',
#  'ااپی',
#  'ااپک',
# ...

# %%
with open("urdu_2.csv","w",encoding="UTF-8")as file:
    filewriter=csv.writer(file)
    filewriter.writerow(lis1)

# %%
lis1=[]
for i in dic.values():
    for k in dic.values():
        for l in dic.values():
            for h in dic.values():
                for g in dic.values():
                    j=i+k+l+h+g
                    lis1.append(j)

# %%
lis1
# Out:
# ['ااااا',
#  'ااااب',
#  'ااااپ',
#  'اااات',
#  'ااااٹ',
#  'ااااث',
#  'ااااج',
#  'ااااد',
#  'ااااص',
#  'ااااط',
#  'اااا',
#  'اااای',
#  'ااااک',
#  'ااااہ',
#  'اااال',
#  'اااان',
#  'اااار',
#  'ااااو',
#  'اااام',
#  'ااااع',
#  'ااااغ',
#  'ااااظ',
#  'ااااض',
#  'ااااذ',
#  'ااااّ',
#  'ااااۃ',
#  'ااااچ',
#  'ااااخ',
#  'ااااي',
#  'ااااگ',
#  'ااااآ',
#  'ااااء',
#  'ااااۂ',
#  'ااااں',
#  'ااااڑ',
#  'ااااز',
#  'ااااژ',
#  'ااااۓ',
#  'اااائ',
#  'ااابا',
#  'ااابب',
#  'ااابپ',
#  'ااابت',
#  'ااابٹ',
#  'ااابث',
#  'ااابج',
#  'ااابد',
#  'ااابص',
#  'ااابط',
#  'اااب',
#  'ااابی',
#  'ااابک',
#  'ااابہ',
#  'ااابل',
#  'ااابن',
#  'ااابر',
#  'ااابو',
#  'ااابم',
#  'ااابع',
#  'ااابغ',
#  'ااابظ',
#  'ااابض',
#  'ااابذ',
#  'ااابّ',
#  'ااابۃ',
#  'ااابچ',
#  'ااابخ',
#  'ااابي',
#  'ااابگ',
#  'ااابآ',
#  'ااابء',
#  'ااابۂ',
#  'ااابں',
#  'ااابڑ',
#  'ااابز',
#  'ااابژ',
#  'ااابۓ',
#  'ااابئ',
#  'اااپا',
#  'اااپب',
#  'اااپپ',
#  'اااپت',
#  'اااپٹ',
# ...

# %%
with open("urdu_3.csv","w",encoding="UTF-8")as file:
    filewriter=csv.writer(file)
    filewriter.writerow(lis1)

# %%
lis1=[]
for i in dic.values():
    for k in dic.values():
        for h in dic.values():
            for f in dic.values():
                for t in dic.values():
                    for u in dic.values():
                        j=i+k+h+f+t+u
                        lis1.append(j)

# %%
lis1

# %%
with open("urdu_4.csv","w",encoding="UTF-8")as file:
    filewriter=csv.writer(file)
    filewriter.writerow(lis1)
